# %%
import pandas as pd
import numpy as np
import random

# %%
random.seed(1)
data = np.genfromtxt("Single_Layer_Perceptron.csv", delimiter=",",skip_header=1)

# %%
data
# Out:
# array([[70.,  1.,  4., ...,  3.,  3.,  2.],
#        [67.,  0.,  3., ...,  0.,  7.,  1.],
#        [57.,  1.,  2., ...,  0.,  7.,  2.],
#        ...,
#        [56.,  0.,  2., ...,  0.,  3.,  1.],
#        [57.,  1.,  4., ...,  0.,  6.,  1.],
#        [67.,  1.,  4., ...,  3.,  3.,  2.]])

# %%
#Split dataset into k folds
def cross_validation_split(dataset, n_folds):
    dataset_split = list()
    dataset_copy = list(dataset)
    fold_size = int(len(dataset)/n_folds)
    for i in range(n_folds):
        fold = list()
        while len(fold) < fold_size :
            index = random.randrange(len(dataset_copy))
            fold.append(dataset_copy.pop(index))
        dataset_split.append(fold)
    return dataset_split

# %%
#Calculate accuracy percentage
def accuracy_metric(actual, predicted):
    correct = 0
    for i in range(len(actual)):
        if actual[i] == predicted[i]:
            correct += 1
    return correct/float(len(actual))*100

# %%
def evaluate_algorithm(dataset, algorithm, n_folds, *args):
    folds = cross_validation_split(dataset, n_folds)
    scores = list()
    for fold in folds:
        train_set = list(folds)
        train_set.remove(fold)
        train_set = sum(train_set, [])
        test_set = list()
        for row in fold:
            row_copy = list(row)
            test_set.append(row_copy)
            row_copy[-1] = None
        predicted = algorithm(train_set, test_set, *args)
        actual = [row[-1] for row in fold]
        accuracy = accuracy_metric(actual, predicted)
        scores.append(accuracy)
    return scores

# %%
#Make a prediction with weights
def predict (row,weights):
    activation = weights[0]
    for i in range(len(row)-1):
        activation += weights[i+1]*row[i]
    return 1.0 if activation>=0 else 0.0

# %%
#Estimate Perceptron weights using stochastic gradient descent 
def train_weights(train, l_rate, n_epoch):
    weights = [0.0 for i in range(len(train[0]))]
    for epoch in range(n_epoch):
        sum_error = 0.0
        for row in train:
            prediction = predict(row, weights)
            error = row[-1] - prediction
            sum_error += error**2
            weights[0] = weights[0] + l_rate*error
            for i in range(len(row)-1):
                weights[i+1] = weights[i+1] + l_rate*error*row[i]
        print(">epoch=%d, lrate=%.3f, error=%.3f" % (epoch, l_rate, sum_error))
    return weights

# %%
# Perceptron Algorithm with Stochastic Gradient Descent
def perceptron(train, test, l_rate, n_epoch):
    predictions = list()
    weights = train_weights(train, l_rate, n_epoch)
    for row in test:
        prediction = predict(row, weights)
        predictions.append(prediction)
    return(predictions)

# %%
n_folds = 3
l_rate = 0.01
n_epoch = 500
weights = [random.random() for i in range(14)]
weights
# Out:
# [0.13436424411240122,
#  0.8474337369372327,
#  0.763774618976614,
#  0.2550690257394217,
#  0.49543508709194095,
#  0.4494910647887381,
#  0.651592972722763,
#  0.7887233511355132,
#  0.0938595867742349,
#  0.02834747652200631,
#  0.8357651039198697,
#  0.43276706790505337,
#  0.762280082457942,
#  0.0021060533511106927]

# %%
correct_count = 0
for row in data:
    prediction  = predict(row, weights)
    print("Excpected=%d, Predicted=%d" %(row[-1], prediction))
    if row[-1]==prediction:
        correct_count += 1
accuracy = correct_count/len(data)
print('The accuracy of the perceptron is', accuracy)
# Out:
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=1, Predicted=1
# Excpected=2, Predicted=1
# The accuracy of the perceptron is 0.5555555555555556

# %%
l_rate = 0.1
n_epoch = 500
weights = train_weights(data, l_rate, n_epoch)
print(weights)
# Out:
# >epoch=0, lrate=0.100, error=120.000
# >epoch=1, lrate=0.100, error=120.000
# >epoch=2, lrate=0.100, error=120.000
# >epoch=3, lrate=0.100, error=120.000
# >epoch=4, lrate=0.100, error=120.000
# >epoch=5, lrate=0.100, error=120.000
# >epoch=6, lrate=0.100, error=120.000
# >epoch=7, lrate=0.100, error=120.000
# >epoch=8, lrate=0.100, error=120.000
# >epoch=9, lrate=0.100, error=120.000
# >epoch=10, lrate=0.100, error=120.000
# >epoch=11, lrate=0.100, error=120.000
# >epoch=12, lrate=0.100, error=120.000
# >epoch=13, lrate=0.100, error=120.000
# >epoch=14, lrate=0.100, error=120.000
# >epoch=15, lrate=0.100, error=120.000
# >epoch=16, lrate=0.100, error=120.000
# >epoch=17, lrate=0.100, error=120.000
# >epoch=18, lrate=0.100, error=120.000
# >epoch=19, lrate=0.100, error=120.000
# >epoch=20, lrate=0.100, error=120.000
# >epoch=21, lrate=0.100, error=120.000
# >epoch=22, lrate=0.100, error=120.000
# >epoch=23, lrate=0.100, error=120.000
# >epoch=24, lrate=0.100, error=120.000
# >epoch=25, lrate=0.100, error=120.000
# >epoch=26, lrate=0.100, error=120.000
# >epoch=27, lrate=0.100, error=120.000
# >epoch=28, lrate=0.100, error=120.000
# >epoch=29, lrate=0.100, error=120.000
# >epoch=30, lrate=0.100, error=120.000
# >epoch=31, lrate=0.100, error=120.000
# >epoch=32, lrate=0.100, error=120.000
# >epoch=33, lrate=0.100, error=120.000
# >epoch=34, lrate=0.100, error=120.000
# >epoch=35, lrate=0.100, error=120.000
# >epoch=36, lrate=0.100, error=120.000
# >epoch=37, lrate=0.100, error=120.000
# >epoch=38, lrate=0.100, error=120.000
# >epoch=39, lrate=0.100, error=120.000
# >epoch=40, lrate=0.100, error=120.000
# >epoch=41, lrate=0.100, error=120.000
# >epoch=42, lrate=0.100, error=120.000
# >epoch=43, lrate=0.100, error=120.000
# >epoch=44, lrate=0.100, error=120.000
# >epoch=45, lrate=0.100, error=120.000
# >epoch=46, lrate=0.100, error=120.000
# >epoch=47, lrate=0.100, error=120.000
# >epoch=48, lrate=0.100, error=120.000
# >epoch=49, lrate=0.100, error=120.000
# >epoch=50, lrate=0.100, error=120.000
# >epoch=51, lrate=0.100, error=120.000
# >epoch=52, lrate=0.100, error=120.000
# >epoch=53, lrate=0.100, error=120.000
# >epoch=54, lrate=0.100, error=120.000
# >epoch=55, lrate=0.100, error=120.000
# >epoch=56, lrate=0.100, error=120.000
# >epoch=57, lrate=0.100, error=120.000
# >epoch=58, lrate=0.100, error=120.000
# >epoch=59, lrate=0.100, error=120.000
# >epoch=60, lrate=0.100, error=120.000
# >epoch=61, lrate=0.100, error=120.000
# >epoch=62, lrate=0.100, error=120.000
# >epoch=63, lrate=0.100, error=120.000
# >epoch=64, lrate=0.100, error=120.000
# >epoch=65, lrate=0.100, error=120.000
# >epoch=66, lrate=0.100, error=120.000
# >epoch=67, lrate=0.100, error=120.000
# >epoch=68, lrate=0.100, error=120.000
# >epoch=69, lrate=0.100, error=120.000
# >epoch=70, lrate=0.100, error=120.000
# >epoch=71, lrate=0.100, error=120.000
# >epoch=72, lrate=0.100, error=120.000
# >epoch=73, lrate=0.100, error=120.000
# >epoch=74, lrate=0.100, error=120.000
# >epoch=75, lrate=0.100, error=120.000
# >epoch=76, lrate=0.100, error=120.000
# >epoch=77, lrate=0.100, error=120.000
# >epoch=78, lrate=0.100, error=120.000
# >epoch=79, lrate=0.100, error=120.000
# >epoch=80, lrate=0.100, error=120.000
# >epoch=81, lrate=0.100, error=120.000
# >epoch=82, lrate=0.100, error=120.000
# >epoch=83, lrate=0.100, error=120.000
# >epoch=84, lrate=0.100, error=120.000
# >epoch=85, lrate=0.100, error=120.000
# >epoch=86, lrate=0.100, error=120.000
# >epoch=87, lrate=0.100, error=120.000
# >epoch=88, lrate=0.100, error=120.000
# >epoch=89, lrate=0.100, error=120.000
# >epoch=90, lrate=0.100, error=120.000
# >epoch=91, lrate=0.100, error=120.000
# >epoch=92, lrate=0.100, error=120.000
# >epoch=93, lrate=0.100, error=120.000
# >epoch=94, lrate=0.100, error=120.000
# >epoch=95, lrate=0.100, error=120.000
# >epoch=96, lrate=0.100, error=120.000
# >epoch=97, lrate=0.100, error=120.000
# >epoch=98, lrate=0.100, error=120.000
# >epoch=99, lrate=0.100, error=120.000
# >epoch=100, lrate=0.100, error=120.000
# >epoch=101, lrate=0.100, error=120.000
# >epoch=102, lrate=0.100, error=120.000
# >epoch=103, lrate=0.100, error=120.000
# >epoch=104, lrate=0.100, error=120.000
# >epoch=105, lrate=0.100, error=120.000
# >epoch=106, lrate=0.100, error=120.000
# >epoch=107, lrate=0.100, error=120.000
# >epoch=108, lrate=0.100, error=120.000
# >epoch=109, lrate=0.100, error=120.000
# >epoch=110, lrate=0.100, error=120.000
# >epoch=111, lrate=0.100, error=120.000
# >epoch=112, lrate=0.100, error=120.000
# >epoch=113, lrate=0.100, error=120.000
# >epoch=114, lrate=0.100, error=120.000
# >epoch=115, lrate=0.100, error=120.000
# >epoch=116, lrate=0.100, error=120.000
# >epoch=117, lrate=0.100, error=120.000
# >epoch=118, lrate=0.100, error=120.000
# >epoch=119, lrate=0.100, error=120.000
# >epoch=120, lrate=0.100, error=120.000
# >epoch=121, lrate=0.100, error=120.000
# >epoch=122, lrate=0.100, error=120.000
# >epoch=123, lrate=0.100, error=120.000
# >epoch=124, lrate=0.100, error=120.000
# >epoch=125, lrate=0.100, error=120.000
# >epoch=126, lrate=0.100, error=120.000
# >epoch=127, lrate=0.100, error=120.000
# >epoch=128, lrate=0.100, error=120.000
# >epoch=129, lrate=0.100, error=120.000
# >epoch=130, lrate=0.100, error=120.000
# >epoch=131, lrate=0.100, error=120.000
# >epoch=132, lrate=0.100, error=120.000
# >epoch=133, lrate=0.100, error=120.000
# >epoch=134, lrate=0.100, error=120.000
# >epoch=135, lrate=0.100, error=120.000
# >epoch=136, lrate=0.100, error=120.000
# >epoch=137, lrate=0.100, error=120.000
# >epoch=138, lrate=0.100, error=120.000
# >epoch=139, lrate=0.100, error=120.000
# >epoch=140, lrate=0.100, error=120.000
# >epoch=141, lrate=0.100, error=120.000
# >epoch=142, lrate=0.100, error=120.000
# >epoch=143, lrate=0.100, error=120.000
# >epoch=144, lrate=0.100, error=120.000
# >epoch=145, lrate=0.100, error=120.000
# >epoch=146, lrate=0.100, error=120.000
# >epoch=147, lrate=0.100, error=120.000
# >epoch=148, lrate=0.100, error=120.000
# >epoch=149, lrate=0.100, error=120.000
# >epoch=150, lrate=0.100, error=120.000
# >epoch=151, lrate=0.100, error=120.000
# >epoch=152, lrate=0.100, error=120.000
# >epoch=153, lrate=0.100, error=120.000
# >epoch=154, lrate=0.100, error=120.000
# >epoch=155, lrate=0.100, error=120.000
# >epoch=156, lrate=0.100, error=120.000
# >epoch=157, lrate=0.100, error=120.000
# >epoch=158, lrate=0.100, error=120.000
# >epoch=159, lrate=0.100, error=120.000
# >epoch=160, lrate=0.100, error=120.000
# >epoch=161, lrate=0.100, error=120.000
# >epoch=162, lrate=0.100, error=120.000
# >epoch=163, lrate=0.100, error=120.000
# >epoch=164, lrate=0.100, error=120.000
# >epoch=165, lrate=0.100, error=120.000
# >epoch=166, lrate=0.100, error=120.000
# >epoch=167, lrate=0.100, error=120.000
# >epoch=168, lrate=0.100, error=120.000
# >epoch=169, lrate=0.100, error=120.000
# >epoch=170, lrate=0.100, error=120.000
# >epoch=171, lrate=0.100, error=120.000
# >epoch=172, lrate=0.100, error=120.000
# >epoch=173, lrate=0.100, error=120.000
# >epoch=174, lrate=0.100, error=120.000
# >epoch=175, lrate=0.100, error=120.000
# >epoch=176, lrate=0.100, error=120.000
# >epoch=177, lrate=0.100, error=120.000
# >epoch=178, lrate=0.100, error=120.000
# >epoch=179, lrate=0.100, error=120.000
# >epoch=180, lrate=0.100, error=120.000
# >epoch=181, lrate=0.100, error=120.000
# >epoch=182, lrate=0.100, error=120.000
# >epoch=183, lrate=0.100, error=120.000
# >epoch=184, lrate=0.100, error=120.000
# >epoch=185, lrate=0.100, error=120.000
# >epoch=186, lrate=0.100, error=120.000
# >epoch=187, lrate=0.100, error=120.000
# >epoch=188, lrate=0.100, error=120.000
# >epoch=189, lrate=0.100, error=120.000
# >epoch=190, lrate=0.100, error=120.000
# >epoch=191, lrate=0.100, error=120.000
# >epoch=192, lrate=0.100, error=120.000
# >epoch=193, lrate=0.100, error=120.000
# >epoch=194, lrate=0.100, error=120.000
# >epoch=195, lrate=0.100, error=120.000
# >epoch=196, lrate=0.100, error=120.000
# >epoch=197, lrate=0.100, error=120.000
# >epoch=198, lrate=0.100, error=120.000
# >epoch=199, lrate=0.100, error=120.000
# >epoch=200, lrate=0.100, error=120.000
# >epoch=201, lrate=0.100, error=120.000
# >epoch=202, lrate=0.100, error=120.000
# >epoch=203, lrate=0.100, error=120.000
# >epoch=204, lrate=0.100, error=120.000
# >epoch=205, lrate=0.100, error=120.000
# >epoch=206, lrate=0.100, error=120.000
# >epoch=207, lrate=0.100, error=120.000
# >epoch=208, lrate=0.100, error=120.000
# >epoch=209, lrate=0.100, error=120.000
# >epoch=210, lrate=0.100, error=120.000
# >epoch=211, lrate=0.100, error=120.000
# >epoch=212, lrate=0.100, error=120.000
# >epoch=213, lrate=0.100, error=120.000
# >epoch=214, lrate=0.100, error=120.000
# >epoch=215, lrate=0.100, error=120.000
# >epoch=216, lrate=0.100, error=120.000
# >epoch=217, lrate=0.100, error=120.000
# >epoch=218, lrate=0.100, error=120.000
# >epoch=219, lrate=0.100, error=120.000
# >epoch=220, lrate=0.100, error=120.000
# >epoch=221, lrate=0.100, error=120.000
# >epoch=222, lrate=0.100, error=120.000
# >epoch=223, lrate=0.100, error=120.000
# >epoch=224, lrate=0.100, error=120.000
# >epoch=225, lrate=0.100, error=120.000
# >epoch=226, lrate=0.100, error=120.000
# >epoch=227, lrate=0.100, error=120.000
# >epoch=228, lrate=0.100, error=120.000
# >epoch=229, lrate=0.100, error=120.000
# >epoch=230, lrate=0.100, error=120.000
# >epoch=231, lrate=0.100, error=120.000
# >epoch=232, lrate=0.100, error=120.000
# >epoch=233, lrate=0.100, error=120.000
# >epoch=234, lrate=0.100, error=120.000
# >epoch=235, lrate=0.100, error=120.000
# >epoch=236, lrate=0.100, error=120.000
# >epoch=237, lrate=0.100, error=120.000
# >epoch=238, lrate=0.100, error=120.000
# >epoch=239, lrate=0.100, error=120.000
# >epoch=240, lrate=0.100, error=120.000
# >epoch=241, lrate=0.100, error=120.000
# >epoch=242, lrate=0.100, error=120.000
# >epoch=243, lrate=0.100, error=120.000
# >epoch=244, lrate=0.100, error=120.000
# >epoch=245, lrate=0.100, error=120.000
# >epoch=246, lrate=0.100, error=120.000
# >epoch=247, lrate=0.100, error=120.000
# >epoch=248, lrate=0.100, error=120.000
# >epoch=249, lrate=0.100, error=120.000
# >epoch=250, lrate=0.100, error=120.000
# >epoch=251, lrate=0.100, error=120.000
# >epoch=252, lrate=0.100, error=120.000
# >epoch=253, lrate=0.100, error=120.000
# >epoch=254, lrate=0.100, error=120.000
# >epoch=255, lrate=0.100, error=120.000
# >epoch=256, lrate=0.100, error=120.000
# >epoch=257, lrate=0.100, error=120.000
# >epoch=258, lrate=0.100, error=120.000
# >epoch=259, lrate=0.100, error=120.000
# >epoch=260, lrate=0.100, error=120.000
# >epoch=261, lrate=0.100, error=120.000
# >epoch=262, lrate=0.100, error=120.000
# >epoch=263, lrate=0.100, error=120.000
# >epoch=264, lrate=0.100, error=120.000
# >epoch=265, lrate=0.100, error=120.000
# >epoch=266, lrate=0.100, error=120.000
# >epoch=267, lrate=0.100, error=120.000
# >epoch=268, lrate=0.100, error=120.000
# >epoch=269, lrate=0.100, error=120.000
# >epoch=270, lrate=0.100, error=120.000
# >epoch=271, lrate=0.100, error=120.000
# >epoch=272, lrate=0.100, error=120.000
# >epoch=273, lrate=0.100, error=120.000
# >epoch=274, lrate=0.100, error=120.000
# >epoch=275, lrate=0.100, error=120.000
# >epoch=276, lrate=0.100, error=120.000
# >epoch=277, lrate=0.100, error=120.000
# >epoch=278, lrate=0.100, error=120.000
# >epoch=279, lrate=0.100, error=120.000
# >epoch=280, lrate=0.100, error=120.000
# >epoch=281, lrate=0.100, error=120.000
# >epoch=282, lrate=0.100, error=120.000
# >epoch=283, lrate=0.100, error=120.000
# >epoch=284, lrate=0.100, error=120.000
# >epoch=285, lrate=0.100, error=120.000
# >epoch=286, lrate=0.100, error=120.000
# >epoch=287, lrate=0.100, error=120.000
# >epoch=288, lrate=0.100, error=120.000
# >epoch=289, lrate=0.100, error=120.000
# >epoch=290, lrate=0.100, error=120.000
# >epoch=291, lrate=0.100, error=120.000
# >epoch=292, lrate=0.100, error=120.000
# >epoch=293, lrate=0.100, error=120.000
# >epoch=294, lrate=0.100, error=120.000
# >epoch=295, lrate=0.100, error=120.000
# >epoch=296, lrate=0.100, error=120.000
# >epoch=297, lrate=0.100, error=120.000
# >epoch=298, lrate=0.100, error=120.000
# >epoch=299, lrate=0.100, error=120.000
# >epoch=300, lrate=0.100, error=120.000
# >epoch=301, lrate=0.100, error=120.000
# >epoch=302, lrate=0.100, error=120.000
# >epoch=303, lrate=0.100, error=120.000
# >epoch=304, lrate=0.100, error=120.000
# >epoch=305, lrate=0.100, error=120.000
# >epoch=306, lrate=0.100, error=120.000
# >epoch=307, lrate=0.100, error=120.000
# >epoch=308, lrate=0.100, error=120.000
# >epoch=309, lrate=0.100, error=120.000
# >epoch=310, lrate=0.100, error=120.000
# >epoch=311, lrate=0.100, error=120.000
# >epoch=312, lrate=0.100, error=120.000
# >epoch=313, lrate=0.100, error=120.000
# >epoch=314, lrate=0.100, error=120.000
# >epoch=315, lrate=0.100, error=120.000
# >epoch=316, lrate=0.100, error=120.000
# >epoch=317, lrate=0.100, error=120.000
# >epoch=318, lrate=0.100, error=120.000
# >epoch=319, lrate=0.100, error=120.000
# >epoch=320, lrate=0.100, error=120.000
# >epoch=321, lrate=0.100, error=120.000
# >epoch=322, lrate=0.100, error=120.000
# >epoch=323, lrate=0.100, error=120.000
# >epoch=324, lrate=0.100, error=120.000
# >epoch=325, lrate=0.100, error=120.000
# >epoch=326, lrate=0.100, error=120.000
# >epoch=327, lrate=0.100, error=120.000
# >epoch=328, lrate=0.100, error=120.000
# >epoch=329, lrate=0.100, error=120.000
# >epoch=330, lrate=0.100, error=120.000
# >epoch=331, lrate=0.100, error=120.000
# >epoch=332, lrate=0.100, error=120.000
# >epoch=333, lrate=0.100, error=120.000
# >epoch=334, lrate=0.100, error=120.000
# >epoch=335, lrate=0.100, error=120.000
# >epoch=336, lrate=0.100, error=120.000
# >epoch=337, lrate=0.100, error=120.000
# >epoch=338, lrate=0.100, error=120.000
# >epoch=339, lrate=0.100, error=120.000
# >epoch=340, lrate=0.100, error=120.000
# >epoch=341, lrate=0.100, error=120.000
# >epoch=342, lrate=0.100, error=120.000
# >epoch=343, lrate=0.100, error=120.000
# >epoch=344, lrate=0.100, error=120.000
# >epoch=345, lrate=0.100, error=120.000
# >epoch=346, lrate=0.100, error=120.000
# >epoch=347, lrate=0.100, error=120.000
# >epoch=348, lrate=0.100, error=120.000
# >epoch=349, lrate=0.100, error=120.000
# >epoch=350, lrate=0.100, error=120.000
# >epoch=351, lrate=0.100, error=120.000
# >epoch=352, lrate=0.100, error=120.000
# >epoch=353, lrate=0.100, error=120.000
# >epoch=354, lrate=0.100, error=120.000
# >epoch=355, lrate=0.100, error=120.000
# >epoch=356, lrate=0.100, error=120.000
# >epoch=357, lrate=0.100, error=120.000
# >epoch=358, lrate=0.100, error=120.000
# >epoch=359, lrate=0.100, error=120.000
# >epoch=360, lrate=0.100, error=120.000
# >epoch=361, lrate=0.100, error=120.000
# >epoch=362, lrate=0.100, error=120.000
# >epoch=363, lrate=0.100, error=120.000
# >epoch=364, lrate=0.100, error=120.000
# >epoch=365, lrate=0.100, error=120.000
# >epoch=366, lrate=0.100, error=120.000
# >epoch=367, lrate=0.100, error=120.000
# >epoch=368, lrate=0.100, error=120.000
# >epoch=369, lrate=0.100, error=120.000
# >epoch=370, lrate=0.100, error=120.000
# >epoch=371, lrate=0.100, error=120.000
# >epoch=372, lrate=0.100, error=120.000
# >epoch=373, lrate=0.100, error=120.000
# >epoch=374, lrate=0.100, error=120.000
# >epoch=375, lrate=0.100, error=120.000
# >epoch=376, lrate=0.100, error=120.000
# >epoch=377, lrate=0.100, error=120.000
# >epoch=378, lrate=0.100, error=120.000
# >epoch=379, lrate=0.100, error=120.000
# >epoch=380, lrate=0.100, error=120.000
# >epoch=381, lrate=0.100, error=120.000
# >epoch=382, lrate=0.100, error=120.000
# >epoch=383, lrate=0.100, error=120.000
# >epoch=384, lrate=0.100, error=120.000
# >epoch=385, lrate=0.100, error=120.000
# >epoch=386, lrate=0.100, error=120.000
# >epoch=387, lrate=0.100, error=120.000
# >epoch=388, lrate=0.100, error=120.000
# >epoch=389, lrate=0.100, error=120.000
# >epoch=390, lrate=0.100, error=120.000
# >epoch=391, lrate=0.100, error=120.000
# >epoch=392, lrate=0.100, error=120.000
# >epoch=393, lrate=0.100, error=120.000
# >epoch=394, lrate=0.100, error=120.000
# >epoch=395, lrate=0.100, error=120.000
# >epoch=396, lrate=0.100, error=120.000
# >epoch=397, lrate=0.100, error=120.000
# >epoch=398, lrate=0.100, error=120.000
# >epoch=399, lrate=0.100, error=120.000
# >epoch=400, lrate=0.100, error=120.000
# >epoch=401, lrate=0.100, error=120.000
# >epoch=402, lrate=0.100, error=120.000
# >epoch=403, lrate=0.100, error=120.000
# >epoch=404, lrate=0.100, error=120.000
# >epoch=405, lrate=0.100, error=120.000
# >epoch=406, lrate=0.100, error=120.000
# >epoch=407, lrate=0.100, error=120.000
# >epoch=408, lrate=0.100, error=120.000
# >epoch=409, lrate=0.100, error=120.000
# >epoch=410, lrate=0.100, error=120.000
# >epoch=411, lrate=0.100, error=120.000
# >epoch=412, lrate=0.100, error=120.000
# >epoch=413, lrate=0.100, error=120.000
# >epoch=414, lrate=0.100, error=120.000
# >epoch=415, lrate=0.100, error=120.000
# >epoch=416, lrate=0.100, error=120.000
# >epoch=417, lrate=0.100, error=120.000
# >epoch=418, lrate=0.100, error=120.000
# >epoch=419, lrate=0.100, error=120.000
# >epoch=420, lrate=0.100, error=120.000
# >epoch=421, lrate=0.100, error=120.000
# >epoch=422, lrate=0.100, error=120.000
# >epoch=423, lrate=0.100, error=120.000
# >epoch=424, lrate=0.100, error=120.000
# >epoch=425, lrate=0.100, error=120.000
# >epoch=426, lrate=0.100, error=120.000
# >epoch=427, lrate=0.100, error=120.000
# >epoch=428, lrate=0.100, error=120.000
# >epoch=429, lrate=0.100, error=120.000
# >epoch=430, lrate=0.100, error=120.000
# >epoch=431, lrate=0.100, error=120.000
# >epoch=432, lrate=0.100, error=120.000
# >epoch=433, lrate=0.100, error=120.000
# >epoch=434, lrate=0.100, error=120.000
# >epoch=435, lrate=0.100, error=120.000
# >epoch=436, lrate=0.100, error=120.000
# >epoch=437, lrate=0.100, error=120.000
# >epoch=438, lrate=0.100, error=120.000
# >epoch=439, lrate=0.100, error=120.000
# >epoch=440, lrate=0.100, error=120.000
# >epoch=441, lrate=0.100, error=120.000
# >epoch=442, lrate=0.100, error=120.000
# >epoch=443, lrate=0.100, error=120.000
# >epoch=444, lrate=0.100, error=120.000
# >epoch=445, lrate=0.100, error=120.000
# >epoch=446, lrate=0.100, error=120.000
# >epoch=447, lrate=0.100, error=120.000
# >epoch=448, lrate=0.100, error=120.000
# >epoch=449, lrate=0.100, error=120.000
# >epoch=450, lrate=0.100, error=120.000
# >epoch=451, lrate=0.100, error=120.000
# >epoch=452, lrate=0.100, error=120.000
# >epoch=453, lrate=0.100, error=120.000
# >epoch=454, lrate=0.100, error=120.000
# >epoch=455, lrate=0.100, error=120.000
# >epoch=456, lrate=0.100, error=120.000
# >epoch=457, lrate=0.100, error=120.000
# >epoch=458, lrate=0.100, error=120.000
# >epoch=459, lrate=0.100, error=120.000
# >epoch=460, lrate=0.100, error=120.000
# >epoch=461, lrate=0.100, error=120.000
# >epoch=462, lrate=0.100, error=120.000
# >epoch=463, lrate=0.100, error=120.000
# >epoch=464, lrate=0.100, error=120.000
# >epoch=465, lrate=0.100, error=120.000
# >epoch=466, lrate=0.100, error=120.000
# >epoch=467, lrate=0.100, error=120.000
# >epoch=468, lrate=0.100, error=120.000
# >epoch=469, lrate=0.100, error=120.000
# >epoch=470, lrate=0.100, error=120.000
# >epoch=471, lrate=0.100, error=120.000
# >epoch=472, lrate=0.100, error=120.000
# >epoch=473, lrate=0.100, error=120.000
# >epoch=474, lrate=0.100, error=120.000
# >epoch=475, lrate=0.100, error=120.000
# >epoch=476, lrate=0.100, error=120.000
# >epoch=477, lrate=0.100, error=120.000
# >epoch=478, lrate=0.100, error=120.000
# >epoch=479, lrate=0.100, error=120.000
# >epoch=480, lrate=0.100, error=120.000
# >epoch=481, lrate=0.100, error=120.000
# >epoch=482, lrate=0.100, error=120.000
# >epoch=483, lrate=0.100, error=120.000
# >epoch=484, lrate=0.100, error=120.000
# >epoch=485, lrate=0.100, error=120.000
# >epoch=486, lrate=0.100, error=120.000
# >epoch=487, lrate=0.100, error=120.000
# >epoch=488, lrate=0.100, error=120.000
# >epoch=489, lrate=0.100, error=120.000
# >epoch=490, lrate=0.100, error=120.000
# >epoch=491, lrate=0.100, error=120.000
# >epoch=492, lrate=0.100, error=120.000
# >epoch=493, lrate=0.100, error=120.000
# >epoch=494, lrate=0.100, error=120.000
# >epoch=495, lrate=0.100, error=120.000
# >epoch=496, lrate=0.100, error=120.000
# >epoch=497, lrate=0.100, error=120.000
# >epoch=498, lrate=0.100, error=120.000
# >epoch=499, lrate=0.100, error=120.000
# [6000.000000004296, 339550.00000000425, 5000.0000000006585, 21700.000000004966, 806650.0000000144, 1538799.999999894, 850.0000000001247, 7349.9999999956, 833149.9999999391, 3299.999999998094, 78399.99999999754, 10900.000000006112, 6900.0000000014925, 35000.000000004184]

# %%
scores = evaluate_algorithm(data, perceptron, n_folds, l_rate, n_epoch)
print('Scores: %s' % scores)
print('Mean accuracy: %.3f%%' % (sum(scores)/float(len(scores))))
# Out:
# >epoch=0, lrate=0.100, error=88.000
# >epoch=1, lrate=0.100, error=88.000
# >epoch=2, lrate=0.100, error=88.000
# >epoch=3, lrate=0.100, error=88.000
# >epoch=4, lrate=0.100, error=88.000
# >epoch=5, lrate=0.100, error=88.000
# >epoch=6, lrate=0.100, error=88.000
# >epoch=7, lrate=0.100, error=88.000
# >epoch=8, lrate=0.100, error=88.000
# >epoch=9, lrate=0.100, error=88.000
# >epoch=10, lrate=0.100, error=88.000
# >epoch=11, lrate=0.100, error=88.000
# >epoch=12, lrate=0.100, error=88.000
# >epoch=13, lrate=0.100, error=88.000
# >epoch=14, lrate=0.100, error=88.000
# >epoch=15, lrate=0.100, error=88.000
# >epoch=16, lrate=0.100, error=88.000
# >epoch=17, lrate=0.100, error=88.000
# >epoch=18, lrate=0.100, error=88.000
# >epoch=19, lrate=0.100, error=88.000
# >epoch=20, lrate=0.100, error=88.000
# >epoch=21, lrate=0.100, error=88.000
# >epoch=22, lrate=0.100, error=88.000
# >epoch=23, lrate=0.100, error=88.000
# >epoch=24, lrate=0.100, error=88.000
# >epoch=25, lrate=0.100, error=88.000
# >epoch=26, lrate=0.100, error=88.000
# >epoch=27, lrate=0.100, error=88.000
# >epoch=28, lrate=0.100, error=88.000
# >epoch=29, lrate=0.100, error=88.000
# >epoch=30, lrate=0.100, error=88.000
# >epoch=31, lrate=0.100, error=88.000
# >epoch=32, lrate=0.100, error=88.000
# >epoch=33, lrate=0.100, error=88.000
# >epoch=34, lrate=0.100, error=88.000
# >epoch=35, lrate=0.100, error=88.000
# >epoch=36, lrate=0.100, error=88.000
# >epoch=37, lrate=0.100, error=88.000
# >epoch=38, lrate=0.100, error=88.000
# >epoch=39, lrate=0.100, error=88.000
# >epoch=40, lrate=0.100, error=88.000
# >epoch=41, lrate=0.100, error=88.000
# >epoch=42, lrate=0.100, error=88.000
# >epoch=43, lrate=0.100, error=88.000
# >epoch=44, lrate=0.100, error=88.000
# >epoch=45, lrate=0.100, error=88.000
# >epoch=46, lrate=0.100, error=88.000
# >epoch=47, lrate=0.100, error=88.000
# >epoch=48, lrate=0.100, error=88.000
# >epoch=49, lrate=0.100, error=88.000
# >epoch=50, lrate=0.100, error=88.000
# >epoch=51, lrate=0.100, error=88.000
# >epoch=52, lrate=0.100, error=88.000
# >epoch=53, lrate=0.100, error=88.000
# >epoch=54, lrate=0.100, error=88.000
# >epoch=55, lrate=0.100, error=88.000
# >epoch=56, lrate=0.100, error=88.000
# >epoch=57, lrate=0.100, error=88.000
# >epoch=58, lrate=0.100, error=88.000
# >epoch=59, lrate=0.100, error=88.000
# >epoch=60, lrate=0.100, error=88.000
# >epoch=61, lrate=0.100, error=88.000
# >epoch=62, lrate=0.100, error=88.000
# >epoch=63, lrate=0.100, error=88.000
# >epoch=64, lrate=0.100, error=88.000
# >epoch=65, lrate=0.100, error=88.000
# >epoch=66, lrate=0.100, error=88.000
# >epoch=67, lrate=0.100, error=88.000
# >epoch=68, lrate=0.100, error=88.000
# >epoch=69, lrate=0.100, error=88.000
# >epoch=70, lrate=0.100, error=88.000
# >epoch=71, lrate=0.100, error=88.000
# >epoch=72, lrate=0.100, error=88.000
# >epoch=73, lrate=0.100, error=88.000
# >epoch=74, lrate=0.100, error=88.000
# >epoch=75, lrate=0.100, error=88.000
# >epoch=76, lrate=0.100, error=88.000
# >epoch=77, lrate=0.100, error=88.000
# >epoch=78, lrate=0.100, error=88.000
# >epoch=79, lrate=0.100, error=88.000
# >epoch=80, lrate=0.100, error=88.000
# >epoch=81, lrate=0.100, error=88.000
# >epoch=82, lrate=0.100, error=88.000
# >epoch=83, lrate=0.100, error=88.000
# >epoch=84, lrate=0.100, error=88.000
# >epoch=85, lrate=0.100, error=88.000
# >epoch=86, lrate=0.100, error=88.000
# >epoch=87, lrate=0.100, error=88.000
# >epoch=88, lrate=0.100, error=88.000
# >epoch=89, lrate=0.100, error=88.000
# >epoch=90, lrate=0.100, error=88.000
# >epoch=91, lrate=0.100, error=88.000
# >epoch=92, lrate=0.100, error=88.000
# >epoch=93, lrate=0.100, error=88.000
# >epoch=94, lrate=0.100, error=88.000
# >epoch=95, lrate=0.100, error=88.000
# >epoch=96, lrate=0.100, error=88.000
# >epoch=97, lrate=0.100, error=88.000
# >epoch=98, lrate=0.100, error=88.000
# >epoch=99, lrate=0.100, error=88.000
# >epoch=100, lrate=0.100, error=88.000
# >epoch=101, lrate=0.100, error=88.000
# >epoch=102, lrate=0.100, error=88.000
# >epoch=103, lrate=0.100, error=88.000
# >epoch=104, lrate=0.100, error=88.000
# >epoch=105, lrate=0.100, error=88.000
# >epoch=106, lrate=0.100, error=88.000
# >epoch=107, lrate=0.100, error=88.000
# >epoch=108, lrate=0.100, error=88.000
# >epoch=109, lrate=0.100, error=88.000
# >epoch=110, lrate=0.100, error=88.000
# >epoch=111, lrate=0.100, error=88.000
# >epoch=112, lrate=0.100, error=88.000
# >epoch=113, lrate=0.100, error=88.000
# >epoch=114, lrate=0.100, error=88.000
# >epoch=115, lrate=0.100, error=88.000
# >epoch=116, lrate=0.100, error=88.000
# >epoch=117, lrate=0.100, error=88.000
# >epoch=118, lrate=0.100, error=88.000
# >epoch=119, lrate=0.100, error=88.000
# >epoch=120, lrate=0.100, error=88.000
# >epoch=121, lrate=0.100, error=88.000
# >epoch=122, lrate=0.100, error=88.000
# >epoch=123, lrate=0.100, error=88.000
# >epoch=124, lrate=0.100, error=88.000
# >epoch=125, lrate=0.100, error=88.000
# >epoch=126, lrate=0.100, error=88.000
# >epoch=127, lrate=0.100, error=88.000
# >epoch=128, lrate=0.100, error=88.000
# >epoch=129, lrate=0.100, error=88.000
# >epoch=130, lrate=0.100, error=88.000
# >epoch=131, lrate=0.100, error=88.000
# >epoch=132, lrate=0.100, error=88.000
# >epoch=133, lrate=0.100, error=88.000
# >epoch=134, lrate=0.100, error=88.000
# >epoch=135, lrate=0.100, error=88.000
# >epoch=136, lrate=0.100, error=88.000
# >epoch=137, lrate=0.100, error=88.000
# >epoch=138, lrate=0.100, error=88.000
# >epoch=139, lrate=0.100, error=88.000
# >epoch=140, lrate=0.100, error=88.000
# >epoch=141, lrate=0.100, error=88.000
# >epoch=142, lrate=0.100, error=88.000
# >epoch=143, lrate=0.100, error=88.000
# >epoch=144, lrate=0.100, error=88.000
# >epoch=145, lrate=0.100, error=88.000
# >epoch=146, lrate=0.100, error=88.000
# >epoch=147, lrate=0.100, error=88.000
# >epoch=148, lrate=0.100, error=88.000
# >epoch=149, lrate=0.100, error=88.000
# >epoch=150, lrate=0.100, error=88.000
# >epoch=151, lrate=0.100, error=88.000
# >epoch=152, lrate=0.100, error=88.000
# >epoch=153, lrate=0.100, error=88.000
# >epoch=154, lrate=0.100, error=88.000
# >epoch=155, lrate=0.100, error=88.000
# >epoch=156, lrate=0.100, error=88.000
# >epoch=157, lrate=0.100, error=88.000
# >epoch=158, lrate=0.100, error=88.000
# >epoch=159, lrate=0.100, error=88.000
# >epoch=160, lrate=0.100, error=88.000
# >epoch=161, lrate=0.100, error=88.000
# >epoch=162, lrate=0.100, error=88.000
# >epoch=163, lrate=0.100, error=88.000
# >epoch=164, lrate=0.100, error=88.000
# >epoch=165, lrate=0.100, error=88.000
# >epoch=166, lrate=0.100, error=88.000
# >epoch=167, lrate=0.100, error=88.000
# >epoch=168, lrate=0.100, error=88.000
# >epoch=169, lrate=0.100, error=88.000
# >epoch=170, lrate=0.100, error=88.000
# >epoch=171, lrate=0.100, error=88.000
# >epoch=172, lrate=0.100, error=88.000
# >epoch=173, lrate=0.100, error=88.000
# >epoch=174, lrate=0.100, error=88.000
# >epoch=175, lrate=0.100, error=88.000
# >epoch=176, lrate=0.100, error=88.000
# >epoch=177, lrate=0.100, error=88.000
# >epoch=178, lrate=0.100, error=88.000
# >epoch=179, lrate=0.100, error=88.000
# >epoch=180, lrate=0.100, error=88.000
# >epoch=181, lrate=0.100, error=88.000
# >epoch=182, lrate=0.100, error=88.000
# >epoch=183, lrate=0.100, error=88.000
# >epoch=184, lrate=0.100, error=88.000
# >epoch=185, lrate=0.100, error=88.000
# >epoch=186, lrate=0.100, error=88.000
# >epoch=187, lrate=0.100, error=88.000
# >epoch=188, lrate=0.100, error=88.000
# >epoch=189, lrate=0.100, error=88.000
# >epoch=190, lrate=0.100, error=88.000
# >epoch=191, lrate=0.100, error=88.000
# >epoch=192, lrate=0.100, error=88.000
# >epoch=193, lrate=0.100, error=88.000
# >epoch=194, lrate=0.100, error=88.000
# >epoch=195, lrate=0.100, error=88.000
# >epoch=196, lrate=0.100, error=88.000
# >epoch=197, lrate=0.100, error=88.000
# >epoch=198, lrate=0.100, error=88.000
# >epoch=199, lrate=0.100, error=88.000
# >epoch=200, lrate=0.100, error=88.000
# >epoch=201, lrate=0.100, error=88.000
# >epoch=202, lrate=0.100, error=88.000
# >epoch=203, lrate=0.100, error=88.000
# >epoch=204, lrate=0.100, error=88.000
# >epoch=205, lrate=0.100, error=88.000
# >epoch=206, lrate=0.100, error=88.000
# >epoch=207, lrate=0.100, error=88.000
# >epoch=208, lrate=0.100, error=88.000
# >epoch=209, lrate=0.100, error=88.000
# >epoch=210, lrate=0.100, error=88.000
# >epoch=211, lrate=0.100, error=88.000
# >epoch=212, lrate=0.100, error=88.000
# >epoch=213, lrate=0.100, error=88.000
# >epoch=214, lrate=0.100, error=88.000
# >epoch=215, lrate=0.100, error=88.000
# >epoch=216, lrate=0.100, error=88.000
# >epoch=217, lrate=0.100, error=88.000
# >epoch=218, lrate=0.100, error=88.000
# >epoch=219, lrate=0.100, error=88.000
# >epoch=220, lrate=0.100, error=88.000
# >epoch=221, lrate=0.100, error=88.000
# >epoch=222, lrate=0.100, error=88.000
# >epoch=223, lrate=0.100, error=88.000
# >epoch=224, lrate=0.100, error=88.000
# >epoch=225, lrate=0.100, error=88.000
# >epoch=226, lrate=0.100, error=88.000
# >epoch=227, lrate=0.100, error=88.000
# >epoch=228, lrate=0.100, error=88.000
# >epoch=229, lrate=0.100, error=88.000
# >epoch=230, lrate=0.100, error=88.000
# >epoch=231, lrate=0.100, error=88.000
# >epoch=232, lrate=0.100, error=88.000
# >epoch=233, lrate=0.100, error=88.000
# >epoch=234, lrate=0.100, error=88.000
# >epoch=235, lrate=0.100, error=88.000
# >epoch=236, lrate=0.100, error=88.000
# >epoch=237, lrate=0.100, error=88.000
# >epoch=238, lrate=0.100, error=88.000
# >epoch=239, lrate=0.100, error=88.000
# >epoch=240, lrate=0.100, error=88.000
# >epoch=241, lrate=0.100, error=88.000
# >epoch=242, lrate=0.100, error=88.000
# >epoch=243, lrate=0.100, error=88.000
# >epoch=244, lrate=0.100, error=88.000
# >epoch=245, lrate=0.100, error=88.000
# >epoch=246, lrate=0.100, error=88.000
# >epoch=247, lrate=0.100, error=88.000
# >epoch=248, lrate=0.100, error=88.000
# >epoch=249, lrate=0.100, error=88.000
# >epoch=250, lrate=0.100, error=88.000
# >epoch=251, lrate=0.100, error=88.000
# >epoch=252, lrate=0.100, error=88.000
# >epoch=253, lrate=0.100, error=88.000
# >epoch=254, lrate=0.100, error=88.000
# >epoch=255, lrate=0.100, error=88.000
# >epoch=256, lrate=0.100, error=88.000
# >epoch=257, lrate=0.100, error=88.000
# >epoch=258, lrate=0.100, error=88.000
# >epoch=259, lrate=0.100, error=88.000
# >epoch=260, lrate=0.100, error=88.000
# >epoch=261, lrate=0.100, error=88.000
# >epoch=262, lrate=0.100, error=88.000
# >epoch=263, lrate=0.100, error=88.000
# >epoch=264, lrate=0.100, error=88.000
# >epoch=265, lrate=0.100, error=88.000
# >epoch=266, lrate=0.100, error=88.000
# >epoch=267, lrate=0.100, error=88.000
# >epoch=268, lrate=0.100, error=88.000
# >epoch=269, lrate=0.100, error=88.000
# >epoch=270, lrate=0.100, error=88.000
# >epoch=271, lrate=0.100, error=88.000
# >epoch=272, lrate=0.100, error=88.000
# >epoch=273, lrate=0.100, error=88.000
# >epoch=274, lrate=0.100, error=88.000
# >epoch=275, lrate=0.100, error=88.000
# >epoch=276, lrate=0.100, error=88.000
# >epoch=277, lrate=0.100, error=88.000
# >epoch=278, lrate=0.100, error=88.000
# >epoch=279, lrate=0.100, error=88.000
# >epoch=280, lrate=0.100, error=88.000
# >epoch=281, lrate=0.100, error=88.000
# >epoch=282, lrate=0.100, error=88.000
# >epoch=283, lrate=0.100, error=88.000
# >epoch=284, lrate=0.100, error=88.000
# >epoch=285, lrate=0.100, error=88.000
# >epoch=286, lrate=0.100, error=88.000
# >epoch=287, lrate=0.100, error=88.000
# >epoch=288, lrate=0.100, error=88.000
# >epoch=289, lrate=0.100, error=88.000
# >epoch=290, lrate=0.100, error=88.000
# >epoch=291, lrate=0.100, error=88.000
# >epoch=292, lrate=0.100, error=88.000
# >epoch=293, lrate=0.100, error=88.000
# >epoch=294, lrate=0.100, error=88.000
# >epoch=295, lrate=0.100, error=88.000
# >epoch=296, lrate=0.100, error=88.000
# >epoch=297, lrate=0.100, error=88.000
# >epoch=298, lrate=0.100, error=88.000
# >epoch=299, lrate=0.100, error=88.000
# >epoch=300, lrate=0.100, error=88.000
# >epoch=301, lrate=0.100, error=88.000
# >epoch=302, lrate=0.100, error=88.000
# >epoch=303, lrate=0.100, error=88.000
# >epoch=304, lrate=0.100, error=88.000
# >epoch=305, lrate=0.100, error=88.000
# >epoch=306, lrate=0.100, error=88.000
# >epoch=307, lrate=0.100, error=88.000
# >epoch=308, lrate=0.100, error=88.000
# >epoch=309, lrate=0.100, error=88.000
# >epoch=310, lrate=0.100, error=88.000
# >epoch=311, lrate=0.100, error=88.000
# >epoch=312, lrate=0.100, error=88.000
# >epoch=313, lrate=0.100, error=88.000
# >epoch=314, lrate=0.100, error=88.000
# >epoch=315, lrate=0.100, error=88.000
# >epoch=316, lrate=0.100, error=88.000
# >epoch=317, lrate=0.100, error=88.000
# >epoch=318, lrate=0.100, error=88.000
# >epoch=319, lrate=0.100, error=88.000
# >epoch=320, lrate=0.100, error=88.000
# >epoch=321, lrate=0.100, error=88.000
# >epoch=322, lrate=0.100, error=88.000
# >epoch=323, lrate=0.100, error=88.000
# >epoch=324, lrate=0.100, error=88.000
# >epoch=325, lrate=0.100, error=88.000
# >epoch=326, lrate=0.100, error=88.000
# >epoch=327, lrate=0.100, error=88.000
# >epoch=328, lrate=0.100, error=88.000
# >epoch=329, lrate=0.100, error=88.000
# >epoch=330, lrate=0.100, error=88.000
# >epoch=331, lrate=0.100, error=88.000
# >epoch=332, lrate=0.100, error=88.000
# >epoch=333, lrate=0.100, error=88.000
# >epoch=334, lrate=0.100, error=88.000
# >epoch=335, lrate=0.100, error=88.000
# >epoch=336, lrate=0.100, error=88.000
# >epoch=337, lrate=0.100, error=88.000
# >epoch=338, lrate=0.100, error=88.000
# >epoch=339, lrate=0.100, error=88.000
# >epoch=340, lrate=0.100, error=88.000
# >epoch=341, lrate=0.100, error=88.000
# >epoch=342, lrate=0.100, error=88.000
# >epoch=343, lrate=0.100, error=88.000
# >epoch=344, lrate=0.100, error=88.000
# >epoch=345, lrate=0.100, error=88.000
# >epoch=346, lrate=0.100, error=88.000
# >epoch=347, lrate=0.100, error=88.000
# >epoch=348, lrate=0.100, error=88.000
# >epoch=349, lrate=0.100, error=88.000
# >epoch=350, lrate=0.100, error=88.000
# >epoch=351, lrate=0.100, error=88.000
# >epoch=352, lrate=0.100, error=88.000
# >epoch=353, lrate=0.100, error=88.000
# >epoch=354, lrate=0.100, error=88.000
# >epoch=355, lrate=0.100, error=88.000
# >epoch=356, lrate=0.100, error=88.000
# >epoch=357, lrate=0.100, error=88.000
# >epoch=358, lrate=0.100, error=88.000
# >epoch=359, lrate=0.100, error=88.000
# >epoch=360, lrate=0.100, error=88.000
# >epoch=361, lrate=0.100, error=88.000
# >epoch=362, lrate=0.100, error=88.000
# >epoch=363, lrate=0.100, error=88.000
# >epoch=364, lrate=0.100, error=88.000
# >epoch=365, lrate=0.100, error=88.000
# >epoch=366, lrate=0.100, error=88.000
# >epoch=367, lrate=0.100, error=88.000
# >epoch=368, lrate=0.100, error=88.000
# >epoch=369, lrate=0.100, error=88.000
# >epoch=370, lrate=0.100, error=88.000
# >epoch=371, lrate=0.100, error=88.000
# >epoch=372, lrate=0.100, error=88.000
# >epoch=373, lrate=0.100, error=88.000
# >epoch=374, lrate=0.100, error=88.000
# >epoch=375, lrate=0.100, error=88.000
# >epoch=376, lrate=0.100, error=88.000
# >epoch=377, lrate=0.100, error=88.000
# >epoch=378, lrate=0.100, error=88.000
# >epoch=379, lrate=0.100, error=88.000
# >epoch=380, lrate=0.100, error=88.000
# >epoch=381, lrate=0.100, error=88.000
# >epoch=382, lrate=0.100, error=88.000
# >epoch=383, lrate=0.100, error=88.000
# >epoch=384, lrate=0.100, error=88.000
# >epoch=385, lrate=0.100, error=88.000
# >epoch=386, lrate=0.100, error=88.000
# >epoch=387, lrate=0.100, error=88.000
# >epoch=388, lrate=0.100, error=88.000
# >epoch=389, lrate=0.100, error=88.000
# >epoch=390, lrate=0.100, error=88.000
# >epoch=391, lrate=0.100, error=88.000
# >epoch=392, lrate=0.100, error=88.000
# >epoch=393, lrate=0.100, error=88.000
# >epoch=394, lrate=0.100, error=88.000
# >epoch=395, lrate=0.100, error=88.000
# >epoch=396, lrate=0.100, error=88.000
# >epoch=397, lrate=0.100, error=88.000
# >epoch=398, lrate=0.100, error=88.000
# >epoch=399, lrate=0.100, error=88.000
# >epoch=400, lrate=0.100, error=88.000
# >epoch=401, lrate=0.100, error=88.000
# >epoch=402, lrate=0.100, error=88.000
# >epoch=403, lrate=0.100, error=88.000
# >epoch=404, lrate=0.100, error=88.000
# >epoch=405, lrate=0.100, error=88.000
# >epoch=406, lrate=0.100, error=88.000
# >epoch=407, lrate=0.100, error=88.000
# >epoch=408, lrate=0.100, error=88.000
# >epoch=409, lrate=0.100, error=88.000
# >epoch=410, lrate=0.100, error=88.000
# >epoch=411, lrate=0.100, error=88.000
# >epoch=412, lrate=0.100, error=88.000
# >epoch=413, lrate=0.100, error=88.000
# >epoch=414, lrate=0.100, error=88.000
# >epoch=415, lrate=0.100, error=88.000
# >epoch=416, lrate=0.100, error=88.000
# >epoch=417, lrate=0.100, error=88.000
# >epoch=418, lrate=0.100, error=88.000
# >epoch=419, lrate=0.100, error=88.000
# >epoch=420, lrate=0.100, error=88.000
# >epoch=421, lrate=0.100, error=88.000
# >epoch=422, lrate=0.100, error=88.000
# >epoch=423, lrate=0.100, error=88.000
# >epoch=424, lrate=0.100, error=88.000
# >epoch=425, lrate=0.100, error=88.000
# >epoch=426, lrate=0.100, error=88.000
# >epoch=427, lrate=0.100, error=88.000
# >epoch=428, lrate=0.100, error=88.000
# >epoch=429, lrate=0.100, error=88.000
# >epoch=430, lrate=0.100, error=88.000
# >epoch=431, lrate=0.100, error=88.000
# >epoch=432, lrate=0.100, error=88.000
# >epoch=433, lrate=0.100, error=88.000
# >epoch=434, lrate=0.100, error=88.000
# >epoch=435, lrate=0.100, error=88.000
# >epoch=436, lrate=0.100, error=88.000
# >epoch=437, lrate=0.100, error=88.000
# >epoch=438, lrate=0.100, error=88.000
# >epoch=439, lrate=0.100, error=88.000
# >epoch=440, lrate=0.100, error=88.000
# >epoch=441, lrate=0.100, error=88.000
# >epoch=442, lrate=0.100, error=88.000
# >epoch=443, lrate=0.100, error=88.000
# >epoch=444, lrate=0.100, error=88.000
# >epoch=445, lrate=0.100, error=88.000
# >epoch=446, lrate=0.100, error=88.000
# >epoch=447, lrate=0.100, error=88.000
# >epoch=448, lrate=0.100, error=88.000
# >epoch=449, lrate=0.100, error=88.000
# >epoch=450, lrate=0.100, error=88.000
# >epoch=451, lrate=0.100, error=88.000
# >epoch=452, lrate=0.100, error=88.000
# >epoch=453, lrate=0.100, error=88.000
# >epoch=454, lrate=0.100, error=88.000
# >epoch=455, lrate=0.100, error=88.000
# >epoch=456, lrate=0.100, error=88.000
# >epoch=457, lrate=0.100, error=88.000
# >epoch=458, lrate=0.100, error=88.000
# >epoch=459, lrate=0.100, error=88.000
# >epoch=460, lrate=0.100, error=88.000
# >epoch=461, lrate=0.100, error=88.000
# >epoch=462, lrate=0.100, error=88.000
# >epoch=463, lrate=0.100, error=88.000
# >epoch=464, lrate=0.100, error=88.000
# >epoch=465, lrate=0.100, error=88.000
# >epoch=466, lrate=0.100, error=88.000
# >epoch=467, lrate=0.100, error=88.000
# >epoch=468, lrate=0.100, error=88.000
# >epoch=469, lrate=0.100, error=88.000
# >epoch=470, lrate=0.100, error=88.000
# >epoch=471, lrate=0.100, error=88.000
# >epoch=472, lrate=0.100, error=88.000
# >epoch=473, lrate=0.100, error=88.000
# >epoch=474, lrate=0.100, error=88.000
# >epoch=475, lrate=0.100, error=88.000
# >epoch=476, lrate=0.100, error=88.000
# >epoch=477, lrate=0.100, error=88.000
# >epoch=478, lrate=0.100, error=88.000
# >epoch=479, lrate=0.100, error=88.000
# >epoch=480, lrate=0.100, error=88.000
# >epoch=481, lrate=0.100, error=88.000
# >epoch=482, lrate=0.100, error=88.000
# >epoch=483, lrate=0.100, error=88.000
# >epoch=484, lrate=0.100, error=88.000
# >epoch=485, lrate=0.100, error=88.000
# >epoch=486, lrate=0.100, error=88.000
# >epoch=487, lrate=0.100, error=88.000
# >epoch=488, lrate=0.100, error=88.000
# >epoch=489, lrate=0.100, error=88.000
# >epoch=490, lrate=0.100, error=88.000
# >epoch=491, lrate=0.100, error=88.000
# >epoch=492, lrate=0.100, error=88.000
# >epoch=493, lrate=0.100, error=88.000
# >epoch=494, lrate=0.100, error=88.000
# >epoch=495, lrate=0.100, error=88.000
# >epoch=496, lrate=0.100, error=88.000
# >epoch=497, lrate=0.100, error=88.000
# >epoch=498, lrate=0.100, error=88.000
# >epoch=499, lrate=0.100, error=88.000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-02f4348556ab> in <module>
# ----> 1 scores = evaluate_algorithm(data, perceptron, n_folds, l_rate, n_epoch)
#       2 print('Scores: %s' % scores)
#       3 print('Mean accuracy: %.3f%%' % (sum(scores)/float(len(scores))))
#
# <ipython-input-37-1c6d9a63a17b> in evaluate_algorithm(dataset, algorithm, n_folds, *args)
#       4     for fold in folds:
#       5         train_set = list(folds)
# ----> 6         train_set.remove(fold)
#       7         train_set = sum(train_set, [])
#       8         test_set = list()
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
